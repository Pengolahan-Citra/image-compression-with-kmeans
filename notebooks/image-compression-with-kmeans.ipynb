# %% [markdown]
# # Import Modules

# %%
import os
import random
import numpy as np
import numpy.matlib

from skimage import io

# %% [markdown]
# # Show original image

# %%
original_image = io.imread('../images/before-compression/cartoon-mountain.png')

io.imshow(original_image)
io.show()

# %% [markdown]
# # Get width and length from image

# %%
length         = original_image.shape[0]
width          = original_image.shape[1]
original_image = original_image / 255

X = original_image.reshape(original_image.shape[0]*original_image.shape[1], 3)

# %% [markdown]
# # Determine Cluster and Max Iteration

# %%
number_of_cluster = 16
max_iters         = 100

# %% [markdown]
# # Function Initialize centroid

# %%
def init_centroids(X, number_of_clusters):
    c = random.sample(list(X), number_of_clusters)
    
    return c

# %% [markdown]
# # Determine closest centroid for each datapoint (pixel)

# %%
def closest_centroids(X, c):
    number_of_cluster = np.size(c,0)
    idx               = np.zeros((np.size(X,0),1))
    arr               = np.empty((np.size(X,0),1))
    
    for i in range(0,number_of_cluster):
        y    = c[i]
        temp = np.ones((np.size(X,0),1))*y
        b    = np.power(np.subtract(X,temp),2)
        a    = np.sum(b,axis = 1)
        a    = np.asarray(a)
        
        a.resize((np.size(X,0),1))
        arr  = np.append(arr, a, axis=1)
        
    arr = np.delete(arr,0,axis=1)
    idx = np.argmin(arr, axis=1)
    
    return idx

# %% [markdown]
# # Generate

# %%
def compute_centroids(X, idx, number_of_cluster):
    n = np.size(X, 1)
    centroids = np.zeros((number_of_cluster, n))
    
    for i in range(0, number_of_cluster):
        ci           = idx==i
        ci           = ci.astype(int)
        total_number = sum(ci)
        
        ci.resize((np.size(X,0),1))
        
        total_matrix = np.matlib.repmat(ci,1,n)
        ci           = np.transpose(ci)
        total        = np.multiply(X,total_matrix)
        centroids[i] = (1 / total_number) * np.sum(total, axis=0)
        
    return centroids

# %% [markdown]
# # KMeans Clustering

# %%
def run_kMean(X, initial_centroids, max_iters):
    m                  = np.size(X, 0)
    n                  = np.size(X, 1)
    number_of_cluster  = np.size(initial_centroids, 0)
    centroids          = initial_centroids
    previous_centroids = centroids
    idx                = np.zeros((m,1))
    
    for i in range(1,max_iters):
        idx = closest_centroids(X, centroids)
        centroids = compute_centroids(X, idx, number_of_cluster)
        
    return centroids,idx

# %% [markdown]
# # Generate

# %%
initial_centroids = init_centroids(X, number_of_cluster)
centroids, idx    = run_kMean(X, initial_centroids, max_iters)

print(np.shape(centroids))
print(np.shape(idx))
# Out:
# <ipython-input-7-9ed35a28c9c3>:15: RuntimeWarning: divide by zero encountered in long_scalars
#   centroids[i] = (1 / total_number) * np.sum(total, axis=0)
# <ipython-input-7-9ed35a28c9c3>:15: RuntimeWarning: invalid value encountered in multiply
#   centroids[i] = (1 / total_number) * np.sum(total, axis=0)
# (16, 3)
# (1000000,)

# %% [markdown]
# # Generate

# %%
idx         = closest_centroids(X, centroids)
X_recovered = centroids[idx]
X_recovered = np.reshape(X_recovered, (length, width, 3))

print(np.shape(X_recovered))
print(np.shape(X_recovered))
# Out:
# (1000, 1000, 3)
# (1000, 1000, 3)

# %% [markdown]
# # Show image compressed

# %%
image_compressed = io.imsave('../images/after-compression/cartoon-mountain-result.png', X_recovered)
# Out:
# C:\Users\yoela\anaconda3\lib\site-packages\imageio\core\util.py:72: RuntimeWarning: All-NaN slice encountered
#   if dtype_str1.startswith("float") and np.nanmin(im) >= 0 and np.nanmax(im) <= 1:
# C:\Users\yoela\anaconda3\lib\site-packages\imageio\core\util.py:93: RuntimeWarning: All-NaN slice encountered
#   mi = np.nanmin(im)
# C:\Users\yoela\anaconda3\lib\site-packages\imageio\core\util.py:94: RuntimeWarning: All-NaN slice encountered
#   ma = np.nanmax(im)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6505774e405c> in <module>
# ----> 1 image_compressed = io.imsave('../images/after-compression/cartoon-mountain-result.png', X_recovered)
#
# ~\anaconda3\lib\site-packages\skimage\io\_io.py in imsave(fname, arr, plugin, check_contrast, **plugin_args)
#     129     if arr.dtype == bool:
#     130         warn('%s is a boolean image: setting True to 1 and False to 0' % fname)
# --> 131     return call_plugin('imsave', fname, arr, plugin=plugin, **plugin_args)
#     132
#     133
#
# ~\anaconda3\lib\site-packages\skimage\io\manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     208                                (plugin, kind))
#     209
# --> 210     return func(*args, **kwargs)
#     211
#     212
#
# ~\anaconda3\lib\site-packages\imageio\core\functions.py in imwrite(uri, im, format, **kwargs)
#     303     writer = get_writer(uri, format, "i", **kwargs)
#     304     with writer:
# --> 305         writer.append_data(im)
#     306
#     307     # Return a result if there is any
#
# ~\anaconda3\lib\site-packages\imageio\core\format.py in append_data(self, im, meta)
#     500             im = asarray(im)
#     501             # Call
# --> 502             return self._append_data(im, total_meta)
#     503
#     504         def set_meta_data(self, meta):
#
# ~\anaconda3\lib\site-packages\imageio\plugins\pillow.py in _append_data(self, im, meta)
#     361                 im = image_as_uint(im, bitdepth=16)
#     362             else:
# --> 363                 im = image_as_uint(im, bitdepth=8)
#     364             PillowFormat.Writer._append_data(self, im, meta)
#     365
#
# ~\anaconda3\lib\site-packages\imageio\core\util.py in image_as_uint(im, bitdepth)
#      94         ma = np.nanmax(im)
#      95         if not np.isfinite(mi):
# ---> 96             raise ValueError("Minimum image value is not finite")
#      97         if not np.isfinite(ma):
#      98             raise ValueError("Maximum image value is not finite")
#
# ValueError: Minimum image value is not finite

# %%
image_compressed = io.imread('../images/after-compression/cartoon-mountain-result.png')

io.imshow(image_compressed)
io.show()

# %% [markdown]
# # Image size before and after compression with KMeans

# %%
size_before_compression = os.stat('../images/before-compression/cartoon-mountain.png')
size_after_compression = os.stat('../images/after-compression/cartoon-mountain-result.png')

print("Size of image before running K-mean algorithm: ", size_before_compression.st_size/1024,"KB")
print("Size of image after running K-mean algorithm: ", size_after_compression.st_size/1024,"KB")
