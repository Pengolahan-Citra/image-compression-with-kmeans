# %% [markdown]
# # Import Modules

# %%
from skimage import io
from sklearn.cluster import KMeans
import numpy as np

# %% [markdown]
# # Read the Image

# %%
image = io.imread('../images/before-compression/landspace1.jpeg')
io.imshow(image)
io.show()

# %% [markdown]
# # Dimension of the original Image

# %%
rows = image.shape[0]
cols = image.shape[1]

# %% [markdown]
# # Flatten The Image

# %%
image = image.reshape(rows*cols, 3)

# %% [markdown]
# # Implement k-means clustering to form k clusters

# %%
kmeans = KMeans(n_clusters=64)
kmeans.fit(image)
# Out:
# KMeans(n_clusters=64)

# %% [markdown]
# # Replace each pixel value with its nearby centroid

# %%
compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)

# %% [markdown]
# # Reshape the image to original dimension

# %%
compressed_image = compressed_image.reshape(rows, cols, 3)

# %% [markdown]
# # Save and display output image

# %%
io.imsave('../images/after-compression/landspace1-result-2.jpeg', compressed_image)
io.imshow(compressed_image)
io.show()

# %% [markdown]
# # Image size before and after compression with KMeans

# %%
size_before_compression = os.stat('../images/before-compression/landspace1.jpeg')
size_after_compression = os.stat('../images/after-compression/landspace1-result-2.jpeg')

print("Size of image before running K-mean algorithm: ", size_before_compression.st_size/1024,"KB")
print("Size of image after running K-mean algorithm: ", size_after_compression.st_size/1024,"KB")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-12db7b60b455> in <module>
# ----> 1 size_before_compression = os.stat('../images/before-compression/landspace1.jpeg')
#       2 size_after_compression = os.stat('../images/after-compression/landspace1-result-2.jpeg')
#       3
#       4 print("Size of image before running K-mean algorithm: ", size_before_compression.st_size/1024,"KB")
#       5 print("Size of image after running K-mean algorithm: ", size_after_compression.st_size/1024,"KB")
#
# NameError: name 'os' is not defined
