# %% [markdown]
# # Import Modules

# %%
import os
import random
import numpy as np
import numpy.matlib

from skimage import io

# %% [markdown]
# # Show original image

# %%
original_image = io.imread('../images/before-compression/apple.jpg')

io.imshow(original_image)
io.show()

# %% [markdown]
# # Get width and length from image

# %%
length         = original_image.shape[0]
width          = original_image.shape[1]
original_image = original_image / 255

X = original_image.reshape(original_image.shape[0]*original_image.shape[1], 1)

print(original_image.shape[0]*original_image.shape[1])
print(length)
print(width)
print(original_image)
# Out:
# 2263520
# 1204
# 1880
# [[0.58431373 0.59607843 0.61176471 ... 0.29019608 0.29019608 0.29019608]
#  [0.61568627 0.62352941 0.63137255 ... 0.29019608 0.29019608 0.29019608]
#  [0.64705882 0.65490196 0.65882353 ... 0.29019608 0.29019608 0.29019608]
#  ...
#  [0.75294118 0.75294118 0.75294118 ... 0.74509804 0.7372549  0.73333333]
#  [0.75294118 0.75294118 0.75294118 ... 0.74509804 0.7372549  0.73333333]
#  [0.75294118 0.75294118 0.75294118 ... 0.74509804 0.7372549  0.73333333]]

# %% [markdown]
# # Determine Cluster and Max Iteration

# %%
number_of_cluster = 16
max_iters         = 10

# %% [markdown]
# # Function Initialize centroid

# %%
def init_centroids(X, number_of_clusters):
    c = random.sample(list(X), number_of_clusters)
    
    return c

# %% [markdown]
# # Determine closest centroid for each datapoint (pixel)

# %%
def closest_centroids(X, c):
    number_of_cluster = np.size(c,0)
    idx               = np.zeros((np.size(X,0),1))
    arr               = np.empty((np.size(X,0),1))
    
    for i in range(0,number_of_cluster):
        y    = c[i]
        temp = np.ones((np.size(X,0),1))*y
        b    = np.power(np.subtract(X,temp),2)
        a    = np.sum(b,axis = 1)
        a    = np.asarray(a)
        
        a.resize((np.size(X,0),1))
        arr  = np.append(arr, a, axis=1)
        
    arr = np.delete(arr,0,axis=1)
    idx = np.argmin(arr, axis=1)
    
    return idx

# %% [markdown]
# # Generate

# %%
def compute_centroids(X, idx, number_of_cluster):
    n = np.size(X, 1)
    centroids = np.zeros((number_of_cluster, n))
    
    for i in range(0, number_of_cluster):
        ci           = idx==i
        ci           = ci.astype(int)
        total_number = sum(ci)
        
        ci.resize((np.size(X,0),1))
        
        total_matrix = np.matlib.repmat(ci,1,n)
        ci           = np.transpose(ci)
        total        = np.multiply(X,total_matrix)
        centroids[i] = (1 / total_number) * np.sum(total, axis=0)
        
    return centroids

# %% [markdown]
# # KMeans Clustering

# %%
def run_kMean(X, initial_centroids, max_iters):
    m                  = np.size(X, 0)
    n                  = np.size(X, 1)
    number_of_cluster  = np.size(initial_centroids, 0)
    centroids          = initial_centroids
    previous_centroids = centroids
    idx                = np.zeros((m,1))
    
    for i in range(1,max_iters):
        idx = closest_centroids(X, centroids)
        centroids = compute_centroids(X, idx, number_of_cluster)
        
    return centroids,idx

# %% [markdown]
# # Generate

# %%
initial_centroids = init_centroids(X, number_of_cluster)
centroids, idx    = run_kMean(X, initial_centroids, max_iters)

print(np.shape(centroids))
print(np.shape(idx))
print(initial_centroids)
# Out:
# (16, 1)
# (2263520,)
# [array([0.68627451]), array([0.4]), array([0.45098039]), array([0.25098039]), array([0.20392157]), array([0.33333333]), array([0.22352941]), array([0.55686275]), array([0.74509804]), array([0.70196078]), array([0.4627451]), array([0.32156863]), array([0.45882353]), array([0.40784314]), array([0.18431373]), array([0.42745098])]

# %% [markdown]
# # Generate

# %%
idx         = closest_centroids(X, centroids)
X_recovered = centroids[idx]
X_recovered = np.reshape(X_recovered, (length, width, -1))

print(np.shape(X_recovered))
print(np.shape(X_recovered))
# Out:
# (1204, 1880, 1)
# (1204, 1880, 1)

# %%
print(X_recovered)
# Out:
# [[[0.57685952]
#   [0.57685952]
#   [0.63642827]
#   ...
#   [0.30741879]
#   [0.30741879]
#   [0.30741879]]
#
#  [[0.63642827]
#   [0.63642827]
#   [0.63642827]
#   ...
#   [0.30741879]
#   [0.30741879]
#   [0.30741879]]
#
#  [[0.63642827]
#   [0.63642827]
#   [0.63642827]
#   ...
#   [0.30741879]
#   [0.30741879]
#   [0.30741879]]
#
#  ...
#
#  [[0.75253865]
#   [0.75253865]
#   [0.75253865]
#   ...
#   [0.75253865]
#   [0.75253865]
#   [0.75253865]]
#
#  [[0.75253865]
#   [0.75253865]
#   [0.75253865]
#   ...
#   [0.75253865]
#   [0.75253865]
#   [0.75253865]]
#
#  [[0.75253865]
#   [0.75253865]
#   [0.75253865]
#   ...
#   [0.75253865]
#   [0.75253865]
#   [0.75253865]]]

# %% [markdown]
# # Show image compressed

# %%
image_compressed = io.imsave('../images/after-compression/result5.jpg', X_recovered)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
image_compressed = io.imread('../images/after-compression/result5.jpg')

io.imshow(image_compressed)
io.show()

# %% [markdown]
# # Image size before and after compression with KMeans

# %%
size_before_compression = os.stat('../images/before-compression/apple.jpg')
size_after_compression = os.stat('../images/after-compression/result5.jpg')

print("Size of image before running K-mean algorithm: ", size_before_compression.st_size/1024,"KB")
print("Size of image after running K-mean algorithm: ", size_after_compression.st_size/1024,"KB")
# Out:
# Size of image before running K-mean algorithm:  147.50390625 KB
# Size of image after running K-mean algorithm:  160.3671875 KB
